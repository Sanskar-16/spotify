# %%
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv("convertcsv.csv", index_col=0)

df.head()
# Out:
#                playlists/lastModifiedDate playlists/items/0/track/trackName  \
# playlists/name
# 4am                            2022-01-16                Love Songs - Bonus
# chal Mumbai 🤑                  2022-01-20               LOVE. FEAT. ZACARI.
# 👓                              2022-01-20              The Butterfly Effect
# hard/acid tech                 2022-01-14                           Ketchup
# Grind                          2021-12-07                               WHY
#
#                playlists/items/0/track/artistName  \
# playlists/name
# 4am                                   Kaash Paige
# chal Mumbai 🤑                      Kendrick Lamar
# 👓                                  Metodi Hristov
# hard/acid tech                     Noneoftheabove
# Grind                                          NF
#
#                playlists/items/0/track/albumName  \
# playlists/name
# 4am                            Parked Car Convos
# chal Mumbai 🤑                              DAMN.
# ...

# %%
sns.scatterplot(df)
# Out:
# C:\Users\sansk\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-53249458cd2b> in <module>
# ----> 1 sns.scatterplot(df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...
